# %%
#Juliana
#Code to loop through all the files downloaded automatically and create the dataframes for each
#Add all pandas code in the bottom loop 
import numpy as np
import pandas as pd
import os
import glob 

#Declare the Empty list for Classes, otherwise it will be filled with irrelevant data
img_files = []

# set input dir path
# Change path as needed depending on who's running the file
path = '/Users/julianashihadeh/Desktop/fifa-20-complete-player-dataset'

#Change current directory to Images 
os.chdir(path)

for x in glob.glob('./*'):
    img_files.append(x.split('/')[1])
print(img_files)
if 'teams_and_leagues.csv' in img_files:
    img_files.remove('teams_and_leagues.csv')
for i in img_files:
    print(i)
    #Create the pandas dataframe for each csv in here by reading file i
    #Replace the following two lines with the final data extraction code
    df=pd.read_csv(i,sep=",",header="infer",index_col=["sofifa_id"])
    print(df.head())
# Out:
# ['players_15.csv', 'players_16.csv', 'players_17.csv', 'players_18.csv', 'players_19.csv', 'players_20.csv', 'teams_and_leagues.csv']
# players_15.csv
#                                                   player_url  \
# sofifa_id
# 158023     https://sofifa.com/player/158023/lionel-messi/...
# 20801      https://sofifa.com/player/20801/c-ronaldo-dos-...
# 9014       https://sofifa.com/player/9014/arjen-robben/15...
# 41236      https://sofifa.com/player/41236/zlatan-ibrahim...
# 167495     https://sofifa.com/player/167495/manuel-neuer/...
#
#                   short_name                            long_name  age  \
# sofifa_id
# 158023              L. Messi       Lionel Andrés Messi Cuccittini   27
# 20801      Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   29
# 9014               A. Robben                         Arjen Robben   30
# 41236         Z. Ibrahimović                   Zlatan Ibrahimović   32
# ...
