# %%
import numpy as np
import pandas as pd
import os
import glob 

#Declare the Empty list for Classes, otherwise it will be filled with irrelevant data
img_files = []

# set input dir path
# Change path as needed depending on who's running the file
path = 'C:/Users/Gaurav Gandhi/Documents/pattern/fifa20/'

#Change current directory
os.chdir(path)

attribute_columns=["sofifa_id","short_name","long_name","age","height_cm","weight_kg","nationality","club","overall","potential","preferred_foot","international_reputation","weak_foot","skill_moves","work_rate","body_type","player_tags","loaned_from","contract_valid_until","pace","shooting","passing","dribbling","defending","physic","player_traits ","attacking_crossing","attacking_finishing","attacking_heading_accuracy","attacking_short_passing","attacking_volleys","skill_dribbling","skill_curve","skill_fk_accuracy","skill_long_passing","skill_ball_control","movement_acceleration","movement_sprint_speed","movement_agility","movement_reactions","movement_balance","power_shot_power","power_jumping","power_stamina","power_strength","power_long_shots","mentality_aggression","mentality_interceptions","mentality_positioning","mentality_vision","mentality_penalties","mentality_composure","defending_marking","defending_standing_tackle","defending_sliding_tackle","goalkeeping_diving","goalkeeping_handling","goalkeeping_kicking","goalkeeping_positioning","goalkeeping_reflexes"]
attribute_columns1=["age","height_cm","weight_kg","overall","potential","preferred_foot","international_reputation","weak_foot","skill_moves","work_rate","body_type","player_tags","contract_valid_until","pace","shooting","passing","dribbling","defending","physic","player_traits ","attacking_crossing","attacking_finishing","attacking_heading_accuracy","attacking_short_passing","attacking_volleys","skill_dribbling","skill_curve","skill_fk_accuracy","skill_long_passing","skill_ball_control","movement_acceleration","movement_sprint_speed","movement_agility","movement_reactions","movement_balance","power_shot_power","power_jumping","power_stamina","power_strength","power_long_shots","mentality_aggression","mentality_interceptions","mentality_positioning","mentality_vision","mentality_penalties","mentality_composure","defending_marking","defending_standing_tackle","defending_sliding_tackle","goalkeeping_diving","goalkeeping_handling","goalkeeping_kicking","goalkeeping_positioning","goalkeeping_reflexes"]
label_columns=["sofifa_id","ls","st","rs","lw","lf","cf","rf","rw","lam","cam","ram","lm","lcm","cm","rcm","rm","lwb","ldm","cdm","rdm","rwb","lb","lcb","cb","rcb","rb"]


ignored_attributes=["player_url","dob","value_eur","wage_eur","real_face","release_clause_eur","team_jersey_number","joined","nation_jersey_number"]
# Dataframe with feature columns

#Dataframe with label columns
# import glob
# df1= glob.glob('C:/Users/Gaurav Gandhi/Documents/pattern/fifa20/players*.csv')
# filenames = glob('/Users/Phani/Desktop/sales*.csv')
# df= [pd.read_csv(f) for f in df1]
# df = pd.concat([pd.read_csv(f, encoding='latin1') for f in df1, ignore_index=True])

import pandas as pd
path1 = 'C:/Users/Gaurav Gandhi/Documents/pattern/fifa20/players_16.csv'
path2 = 'C:/Users/Gaurav Gandhi/Documents/pattern/fifa20/players_17.csv'
path3 = 'C:/Users/Gaurav Gandhi/Documents/pattern/fifa20/players_18.csv'
path4 = 'C:/Users/Gaurav Gandhi/Documents/pattern/fifa20/players_19.csv'
path = 'C:/Users/Gaurav Gandhi/Documents/pattern/fifa20/players_15.csv'

df=pd.read_csv(path,sep=",",header="infer")
df1=pd.read_csv(path1,sep=",",header="infer")
df2=pd.read_csv(path2,sep=",",header="infer")
df3=pd.read_csv(path3,sep=",",header="infer")
df4=pd.read_csv(path4,sep=",",header="infer")
p= pd.concat([df,df1],ignore_index=True)
p1=pd.concat([p,df2],ignore_index=True)
p2=pd.concat([p1,df3],ignore_index=True)
p3=pd.concat([p2,df4],ignore_index=True)

label_attributes_df=p3.filter(items=label_columns)


label_attributes_df.update(label_attributes_df.fillna("0+0"))

null_sofifa_ids=label_attributes_df[label_attributes_df["ls"].isnull()]["sofifa_id"]

# label_attributes_df=label_attributes_df[label_attributes_df.ls.notnull()]
# label_attributes_df

# %%
# def extract_labels(label_attributes_df):
ids=label_attributes_df.sofifa_id
label_attributes_df.drop(columns=["sofifa_id"],inplace=True)
def split_1(v):
    if '+' in v:
        s= v.split('+')
        return (int(s[0])+int(s[1]))
    elif '-' in v:
        s=v.split('-')
        if s[1].isalpha()== True:
            return 0
        if s[0].isdigit()==False:
            s[0]=0
        if s[1].isdigit()== False:
            s[1]=0
        return abs(int(s[0])-int(s[1]))


p3["gk_positioning"]=p3["gk_positioning"].apply(lambda v: 0 if type(v)==str and len(v)>5 else( split_1(v) if type(v)== str else v))

    
    # Splitting each column values by "+" and storing the addition of splitted values.
    # Ex: label["ls"]= 93+1 =94
for col in label_attributes_df.columns:
    label_attributes_df[col]=label_attributes_df[col].apply(lambda v:v.split('+')).apply(lambda s: int(s[0])+int(s[1]))

# %%
label_attributes_df=label_attributes_df[label_attributes_df.apply(lambda x: x == label_attributes_df.max(axis = 1))] 
label_attributes_df.insert(0,"gk_positioning",p3["gk_positioning"],allow_duplicates=True)
label_attributes_df.replace(0.0,np.nan,inplace=True)
# label_attributes_df

# %%
newdf = label_attributes_df.notnull().astype('int')
newdf["ls"][2:40]
# Out:
# 2     0
# 3     1
# 4     0
# 5     0
# 6     0
# 7     0
# 8     0
# 9     0
# 10    1
# 11    0
# 12    1
# 13    0
# 14    0
# 15    0
# 16    0
# 17    0
# 18    0
# 19    0
# 20    0
# 21    0
# 22    0
# 23    0
# 24    1
# 25    0
# 26    0
# 27    0
# 28    0
# 29    1
# 30    0
# 31    0
# 32    0
# 33    0
# 34    1
# 35    1
# 36    1
# 37    0
# 38    0
# 39    0
# Name: ls, dtype: int32

# %%
attribute_columns1=["age","height_cm","weight_kg","gk_diving","overall","nationality","club","potential","preferred_foot","international_reputation","weak_foot","skill_moves","body_type","contract_valid_until","pace","shooting","passing","dribbling","defending","physic"]
attribute_df=p3.filter(items=attribute_columns1)
work_rate_attack=[]
work_rate_defense=[]
for col in p3["work_rate"]:
    a,b=col.split('/')
    work_rate_attack.append(a)
    work_rate_defense.append(b)

attribute_df.insert(5,"attack_work_rate",work_rate_attack,allow_duplicates=True)
attribute_df.insert(5,"defense_work_rate",work_rate_defense,allow_duplicates=True)

labels = attribute_df["attack_work_rate"].unique().tolist()
nat_l= attribute_df["nationality"].unique().tolist()
club_l=attribute_df["club"].unique().tolist()
foot= attribute_df["preferred_foot"].unique().tolist()
body=attribute_df["body_type"].unique().tolist()

bt=dict(zip(body,range(len(body))))
mapping = dict(zip(labels,range(len(labels))))
f = dict(zip(foot,range(len(foot))))
nat=dict(zip(nat_l,range(len(nat_l))))
cl=dict(zip(club_l,range(len(club_l))))
attribute_df.replace({"body_type": bt, "attack_work_rate": mapping, "defense_work_rate": mapping,"preferred_foot": f,"nationality": nat,"club":cl},inplace=True)
    
attribute_df.update(attribute_df.fillna(0))
x=p3[p3["player_tags"].notnull()]



tags=[]
taglist=[]
for col in p3["player_tags"]:
    tag_index=[]
    if type(col) is str:
        " ".join(col.split())
        current_tags=col.split(',')
        for t in current_tags:
            t=t.strip()
            if t not in tags:
                tags.append(t)
            tag_index.append(tags.index(t))
        taglist.append(tag_index)
    else:
        tag_index.append(-1)
        taglist.append(tag_index)

for t in tags:
    attribute_df.insert(7,t,0)
i=0
for col in p3["player_tags"]:
    tag_index=[]
    if type(col) is str:
        " ".join(col.split())
        current_tags=col.split(',')
        for t in current_tags:
            t=t.strip()
            c=attribute_df.columns.get_loc(t)
            attribute_df.iloc[i,c]=1
    i+=1            
        
traits=[]
# tags=[]
traitlist=[]
# taglist=[]

for col in p3["player_traits"]:
    trait_index=[]
    if type(col) is str:
        " ".join(col.split())
        current_traits=col.split(',')
        for t in current_traits:
            t=t.strip()
            if t not in traits:
                traits.append(t)
            trait_index.append(traits.index(t))
        traitlist.append(trait_index)
    else:
        trait_index.append(-1)
        traitlist.append(trait_index)

for t in traits:
    attribute_df.insert(12,t,0)

i=0
for col in p3["player_traits"]:
    trait_index=[]
    if type(col) is str:
        " ".join(col.split())
        current_tags=col.split(',')
        for t in current_tags:
            t=t.strip()
            c=attribute_df.columns.get_loc(t)
            attribute_df.iloc[i,c]=1
    i+=1      
# traitlist = ["A", "B", "C"]
attribute_df
# Out:
#        age  height_cm  weight_kg  gk_diving  overall  defense_work_rate  \
# 0       27        169         67        0.0       93                  2
# 1       29        185         80        0.0       92                  2
# 2       30        180         80        0.0       90                  2
# 3       32        195         95        0.0       90                  2
# 4       28        193         92       87.0       90                  0
# ...    ...        ...        ...        ...      ...                ...
# 82712   19        180         72        0.0       47                  0
# 82713   18        178         75        0.0       47                  0
# 82714   20        181         64        0.0       47                  0
# 82715   19        179         73        0.0       47                  0
# 82716   19        180         72        0.0       47                  0
#
#        attack_work_rate  #Complete Midfielder  #Crosser  #Complete Defender  \
# ...

# %%
attribute_filter=["attacking_crossing","attacking_finishing","attacking_heading_accuracy","attacking_short_passing","attacking_volleys","skill_dribbling","skill_curve","skill_fk_accuracy","skill_long_passing","skill_ball_control","movement_acceleration","movement_sprint_speed","movement_agility","movement_reactions","movement_balance","power_shot_power","power_jumping","power_stamina","power_strength","power_long_shots","mentality_aggression","mentality_interceptions","mentality_positioning","mentality_vision","mentality_penalties","defending_marking","defending_standing_tackle","defending_sliding_tackle"]
attri_df=p3.filter(attribute_filter)
attri_df.update(attri_df.fillna(0))

# print(attri_df.iloc[45465]["mentality_positioning"])
def split_f(v):
    if '+' in v:
        s= v.split('+')
        return (int(s[0])+int(s[1]))
    elif '-' in v:
        s=v.split('-')
        if len(s)== 1:
            return int(s[0])
        if s[1].isalpha()== True:
            return 0
        if s[0].isdigit()==False:
            s[0]=0
        if s[1].isdigit()== False:
            s[1]=0
        return int(abs(int(s[0])-int(s[1])))

for col in attri_df.columns:
    attri_df[col]=attri_df[col].apply(lambda v: 0 if type(v)==str and len(v)>5 else( split_f(v) if type(v)== str and len(v)>2 else v))
attri_df
# Out:
#       attacking_crossing attacking_finishing attacking_heading_accuracy  \
# 0                     84                  91                         71
# 1                     83                  98                         86
# 2                     80                  87                         50
# 3                     76                  91                         76
# 4                     25                  25                         25
# ...                  ...                 ...                        ...
# 82712                 31                  26                         49
# 82713                 37                  48                         30
# 82714                 40                  27                         45
# 82715                 39                  40                         45
# 82716                 37                  34                         49
#
#       attacking_short_passing attacking_volleys skill_dribbling skill_curve  \
# ...

# %%
attri_df.iloc[45465]["mentality_positioning"]
# Out:
# 5

# %%
train_df = pd.concat([attri_df.reset_index(drop=True),attribute_df.reset_index(drop=True)], axis=1)
# train_df = pd.concat([newdf.reset_index(drop=True),train_df.reset_index(drop=True)], axis=1)

with open(r'C:\Users\Gaurav Gandhi\Documents\pattern\fifa20\Traits.txt', 'w') as filehandle:
    for listitem in traits:
        filehandle.write('%s\n' % listitem)

with open(r'C:\Users\Gaurav Gandhi\Documents\pattern\fifa20\Tags.txt', 'w') as filehandle:
    for listitem in tags:
        filehandle.write('%s\n' % listitem)

train_df
# Out:
#       attacking_crossing attacking_finishing attacking_heading_accuracy  \
# 0                     84                  91                         71
# 1                     83                  98                         86
# 2                     80                  87                         50
# 3                     76                  91                         76
# 4                     25                  25                         25
# ...                  ...                 ...                        ...
# 82712                 31                  26                         49
# 82713                 37                  48                         30
# 82714                 40                  27                         45
# 82715                 39                  40                         45
# 82716                 37                  34                         49
#
#       attacking_short_passing attacking_volleys skill_dribbling skill_curve  \
# ...

# %%
train_df.to_csv (r'C:\Users\Gaurav Gandhi\Documents\pattern\fifa20\train1.csv', index = False, header=True) #Don't forget to add '.csv' at the end of the path
newdf.to_csv (r'C:\Users\Gaurav Gandhi\Documents\pattern\fifa20\train_labels.csv', index = False, header=True) #Don't forget to add '.csv' at the end of the path
